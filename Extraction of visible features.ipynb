# %% [markdown]
# <a href="https://colab.research.google.com/github/bassamalasadi/Thesis/blob/master/Extraction%20of%20visible%20features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install cvlib

# %%
# import libraries
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = '5.jpg'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)

print("[INFO] Found {0} Faces.".format(len(faces)))

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    h = h // 2
    roi_color = image[y:y + h, x:x + w]
    print("[INFO] Object found. Saving locally.")
    cv2.imwrite(str(w) + str(h) + '_faces.jpg', roi_color)
    plt.imshow(roi_color)
# status = cv2.imwrite('faces_detected.jpg', image)
# print("[INFO] Image faces_detected.jpg written to filesystem: ", status)
# Out:
# [INFO] Found 1 Faces.
# [INFO] Object found. Saving locally.

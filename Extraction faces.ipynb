# %% [markdown]
# <a href="https://colab.research.google.com/github/bassamalasadi/Thesis/blob/master/Extraction%20faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.1MB 3.5MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.5-cp36-none-any.whl size=10044204 sha256=6e4c1de729c01bb0f24780238294f9e8ecc735996d7deb6a6ba9dba6ec222460
#   Stored in directory: /root/.cache/pip/wheels/6a/cb/43/ba188c823836640d8f22ee1f6ff792a0c83a8b66eabf52b219
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12074 sha256=66f5136c41c6e9cadf3c1e0ef4c88e1ae3ef3561367816ecd0f57e84a1b83f2d
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...

# %%
# import libraries
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = '1.jpg'
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)

print("[INFO] Found {0} Faces.".format(len(faces)))

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    # h = h // 2
    roi_color = image[y:y + h, x:x + w]
    print("[INFO] Object found. Saving locally.")
    cv2.imwrite('face.jpg', roi_color)
    plt.imshow(roi_color)
# status = cv2.imwrite('faces_detected.jpg', image)
# print("[INFO] Image faces_detected.jpg written to filesystem: ", status)
# Out:
# [INFO] Found 1 Faces.
# [INFO] Object found. Saving locally.

# %%
pip install fastai

# %%
from fastai.vision import *

# %%
pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# ...
#      |████████████████████████████████| 753.4MB 15kB/s
# ...
#      |████████████████████████████████| 4.0MB 35.5MB/s
# ...
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# ...

# %%
path=Path('./')

# %%
learn = load_learner(path)

# %%
img = open_image(path/'face.jpg')
img
# Out:
# Image (3, 283, 283)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
print(pred_class)
# Out:
# With-Mask
